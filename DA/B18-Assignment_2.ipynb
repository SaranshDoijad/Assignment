# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
football = pd.read_csv('/Users/saran/Downloads/Fifa.csv')

# %%
football.head(5)
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %%
football_sort = football.sort_values(by = 'possession team1',ascending  = False).head()
football_sort.head()
# Out:
#         team1         team2 possession team1 possession team2  \
# 10      SPAIN    COSTA RICA              74%              17%
# 1     ENGLAND          IRAN              72%              19%
# 9     GERMANY         JAPAN              65%              22%
# 4   ARGENTINA  SAUDI ARABIA              64%              24%
# 7      FRANCE     AUSTRALIA              56%              35%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 10                    9%                      7                      0
# 1                     9%                      6                      2
# 9                    13%                      1                      2
# 4                    12%                      1                      2
# 7                     9%                      4                      1
#
#            date     hour category  ...  penalties scored team1  \
# 10  23 NOV 2022  17 : 00  Group E  ...                       1
# ...

# %%
football_sort = football.sort_values(by = 'team1',ascending  = False).head()
football_sort.head()
# Out:
#             team1           team2 possession team1 possession team2  \
# 16          WALES            IRAN              51%              33%
# 34          WALES         ENGLAND              33%              58%
# 13        URUGUAY  KOREA REPUBLIC              49%              38%
# 3   UNITED STATES           WALES              51%              39%
# 20        TUNISIA       AUSTRALIA              50%              31%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 16                   16%                      0                      2
# 34                   10%                      0                      3
# 13                   13%                      0                      0
# 3                    10%                      1                      1
# 20                   19%                      0                      1
#
#            date     hour category  ...  penalties scored team1  \
# ...

# %%
plt.hist(football['team1'],20)
# Out:
# (array([6., 2., 5., 2., 4., 4., 2., 3., 1., 6., 6., 2., 5., 4., 4., 1., 2.,
#         1., 2., 2.]),
#  array([ 0.  ,  1.55,  3.1 ,  4.65,  6.2 ,  7.75,  9.3 , 10.85, 12.4 ,
#         13.95, 15.5 , 17.05, 18.6 , 20.15, 21.7 , 23.25, 24.8 , 26.35,
#         27.9 , 29.45, 31.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.distplot(football['number of goals team1'],bins = 10)
# Out:
# H:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number of goals team1', ylabel='Density'>

# %%
team1_dist = football.groupby('team1').size()
team1_dist
# Out:
# team1
# ARGENTINA         5
# AUSTRALIA         1
# BELGIUM           2
# BRAZIL            3
# CAMEROON          2
# CANADA            1
# COSTA RICA        1
# CROATIA           4
# DENMARK           1
# ECUADOR           1
# ENGLAND           4
# FRANCE            4
# GERMANY           1
# GHANA             1
# IRAN              1
# JAPAN             3
# KOREA REPUBLIC    2
# MEXICO            1
# MOROCCO           3
# NETHERLANDS       4
# POLAND            2
# PORTUGAL          3
# QATAR             2
# SAUDI ARABIA      1
# SENEGAL           1
# SERBIA            1
# SPAIN             2
# SWITZERLAND       1
# TUNISIA           2
# UNITED STATES     1
# URUGUAY           1
# WALES             2
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

data=football[['penalties scored team1','penalties scored team2','goal preventions team1']]
scaler = MinMaxScaler()
data_normalized=scaler.fit_transform(data)
football[['team1','team2','possession team1']]=data_normalized
print(data_normalized)
# Out:
# [[0.      0.5     0.1875 ]
#  [0.      0.5     0.25   ]
#  [0.      0.      0.28125]
#  [0.      0.5     0.21875]
#  [1.      0.      0.125  ]
#  [0.      0.      0.34375]
#  [0.      0.      0.25   ]
#  [0.      0.      0.125  ]
#  [0.      0.      0.21875]
#  [1.      0.      0.375  ]
#  [1.      0.      0.     ]
#  [0.      0.      0.65625]
#  [0.      0.      0.21875]
#  [0.      0.      0.1875 ]
#  [1.      0.      0.25   ]
#  [0.      0.      0.125  ]
#  [0.      0.      0.65625]
#  [0.      0.      0.375  ]
#  [0.      0.      0.4375 ]
#  [0.      0.      0.3125 ]
#  [0.      0.      0.28125]
#  [0.      0.      0.5    ]
#  [0.      0.      0.3125 ]
#  [0.      0.      0.125  ]
#  [0.      0.      0.125  ]
#  [0.      0.      0.34375]
#  [0.      0.      0.28125]
#  [0.      0.      0.34375]
#  [0.      0.      0.5    ]
#  [0.      0.      0.25   ]
#  [0.      0.      0.125  ]
#  [1.      0.      0.34375]
#  [0.      0.      0.15625]
#  [0.      0.5     0.46875]
# ...

# %%
football_temp=football.copy()
football_temp['team1'] = (football_temp['team1']-football_temp['team1'].min())/(football_temp['team1'].max()-football_temp['team1'].min())
sns.distplot(football_temp['team1'])
# Out:
# H:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='team1', ylabel='Density'>

# %%
sample_mean = football['team1'].mean()

# %%
sample_mean
# Out:
# 0.140625

# %%
sample_deviation = football['team1'].std()

# %%
sample_deviation
# Out:
# 0.35038244411336755

# %%
z_score =(football['team1'] - sample_mean)/sample_deviation
z_score
# Out:
# 0    -0.401347
# 1    -0.401347
# 2    -0.401347
# 3    -0.401347
# 4     2.452677
#         ...
# 59    2.452677
# 60    2.452677
# 61   -0.401347
# 62   -0.401347
# 63    2.452677
# Name: team1, Length: 64, dtype: float64
